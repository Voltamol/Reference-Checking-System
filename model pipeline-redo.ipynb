# %%
from sklearn.feature_extraction.text import CountVectorizer,TfidfTransformer
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
import numpy as np
import pandas as pd

# %%
model=Pipeline([
    ('count_vectorizer',CountVectorizer()),
    ('transformer',TfidfTransformer()),
    ('model',RandomForestClassifier())
])

# %%
data=pd.read_csv('employee_sentiments.csv')

# %%
x_train,x_test,y_train,y_test=train_test_split(data['feedback_clean'],data['performance_class'])

# %%
model.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('count_vectorizer', CountVectorizer()),
#                 ('transformer', TfidfTransformer()),
#                 ('model', RandomForestClassifier())])

# %%
x_test
# Out:
# 278    dylan is currently a underperforming worker mo...
# 351    rebecca consistently completes her work but do...
# 457    dallas is a very proficient worker he ha the k...
# 38     lexi rogers doe not meet expectation with the ...
# 134    michael is having a good quarter he doesnt mak...
#                              ...
# 157    bailey hunter daily production oscillates from...
# 181    surreal is how i describe the achievement of e...
# 28     jude ha potential but need coaching in several...
# 535    patricia met all requirement of her role this ...
# 265    camille doe not put in the same level of effor...
# Name: feedback_clean, Length: 164, dtype: object

# %%
sample=x_test.iloc[0]

# %%
sample
# Out:
# 'dylan is currently a underperforming worker most of his work is below quality and he ha trouble meeting deadline he is not very detail oriented and miss small information here and there however he is eager to learn and improve himself and responds well to feedback he often learns from mistake and ha shown moderate progress although he is currently a weaker worker he may be able to improve with lot of guidance'

# %%
model.predict(np.array([sample]))
# Out:
# array([0], dtype=int64)

# %%
data.head()
# Out:
#                                       feedback_clean  performance_class  \
# 0  john ha not progressed in his position he is c...                  0
# 1  douglas henry ha been having trouble in all ar...                  0
# 2  douglas ha a lot to work on and area to grow i...                  0
# 3  freddie is a nice guy but his performance and ...                  0
# 4  freddie ha been quite disappointing this quart...                  0
#
#   sentiment_label
# 0        negative
# 1        negative
# 2        negative
# 3        negative
# 4        negative

# %%
labels=dict(zip(data['performance_class'],data['sentiment_label']))

# %%
labels
# Out:
# {0: 'negative', 1: 'positive', 2: 'neutral'}

# %%
x_test
# Out:
# 278    dylan is currently a underperforming worker mo...
# 351    rebecca consistently completes her work but do...
# 457    dallas is a very proficient worker he ha the k...
# 38     lexi rogers doe not meet expectation with the ...
# 134    michael is having a good quarter he doesnt mak...
#                              ...
# 157    bailey hunter daily production oscillates from...
# 181    surreal is how i describe the achievement of e...
# 28     jude ha potential but need coaching in several...
# 535    patricia met all requirement of her role this ...
# 265    camille doe not put in the same level of effor...
# Name: feedback_clean, Length: 164, dtype: object

# %%
sample2=x_test.iloc[2]

# %%
sample2
# Out:
# 'dallas is a very proficient worker he ha the knowledge to complete task and often completes them on time or early he occasionally struggle to seek out new opportunity but he applies himself when asked dallas prof he ha the ability to work in this role and excels with his execution of task presented to him'

# %%
def classify(comment):
    arr=np.array([comment])
    probabilities = model.predict_proba(arr)[0]
    labels=['negative','positive','neutral']
    return dict(zip(labels,probabilities))

# %%
classify(sample2)
# Out:
# {'negative': 0.33, 'positive': 0.36, 'neutral': 0.31}

# %%
classify('he is the worst salesman I have ever seen in my life')
# Out:
# {'negative': 0.26, 'positive': 0.31, 'neutral': 0.43}

# %%
classify('he sucks at some stuff but is willing to learn')
# Out:
# {'negative': 0.21, 'positive': 0.34, 'neutral': 0.45}

# %%
classify('does not show up on time but he knows how to write good code')
# Out:
# {'negative': 0.44, 'positive': 0.36, 'neutral': 0.2}

# %%
import pickle

# %%
with open('model.pickle','wb') as binary:
    pickle.dump(model,binary)
